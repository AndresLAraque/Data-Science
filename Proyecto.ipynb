# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm
import numpy as np
# %matplotlib inline

# %%
migracion = pd.read_csv("WDI_csv/WDIData.csv", index_col=0)
migracion.head()
# Out:
#                             Country Code  \
# Country Name
# Africa Eastern and Southern          AFE
# Africa Eastern and Southern          AFE
# Africa Eastern and Southern          AFE
# Africa Eastern and Southern          AFE
# Africa Eastern and Southern          AFE
#
#                                                                 Indicator Name  \
# Country Name
# Africa Eastern and Southern  Access to clean fuels and technologies for coo...
# Africa Eastern and Southern            Access to electricity (% of population)
# Africa Eastern and Southern  Access to electricity, rural (% of rural popul...
# Africa Eastern and Southern  Access to electricity, urban (% of urban popul...
# Africa Eastern and Southern  Account ownership at a financial institution o...
#
#                                 Indicator Code  1960  1961  1962  1963  1964  \
# Country Name
# Africa Eastern and Southern     EG.CFT.ACCS.ZS   NaN   NaN   NaN   NaN   NaN
# ...

# %%
origen = pd.read_csv("WDI_csv/WDICountry.csv", index_col=0)
origen.head()
# Out:
#                                Short Name                   Table Name  \
# Country Code
# ABW                                 Aruba                        Aruba
# AFE           Africa Eastern and Southern  Africa Eastern and Southern
# AFG                           Afghanistan                  Afghanistan
# AFW            Africa Western and Central   Africa Western and Central
# AGO                                Angola                       Angola
#
#                                  Long Name 2-alpha code   Currency Unit  \
# Country Code
# ABW                                  Aruba           AW   Aruban florin
# AFE            Africa Eastern and Southern           ZH             NaN
# AFG           Islamic State of Afghanistan           AF  Afghan afghani
# AFW             Africa Western and Central           ZI             NaN
# AGO            People's Republic of Angola           AO  Angolan kwanza
#
#                                                   Special Notes  \
# ...

# %%
migracion['probando']=migracion['Indicator Code']
migracion.head()
# Out:
#                             Country Code  \
# Country Name
# Africa Eastern and Southern          AFE
# Africa Eastern and Southern          AFE
# Africa Eastern and Southern          AFE
# Africa Eastern and Southern          AFE
# Africa Eastern and Southern          AFE
#
#                                                                 Indicator Name  \
# Country Name
# Africa Eastern and Southern  Access to clean fuels and technologies for coo...
# Africa Eastern and Southern            Access to electricity (% of population)
# Africa Eastern and Southern  Access to electricity, rural (% of rural popul...
# Africa Eastern and Southern  Access to electricity, urban (% of urban popul...
# Africa Eastern and Southern  Account ownership at a financial institution o...
#
#                                 Indicator Code  1960  1961  1962  1963  1964  \
# Country Name
# Africa Eastern and Southern     EG.CFT.ACCS.ZS   NaN   NaN   NaN   NaN   NaN
# ...
